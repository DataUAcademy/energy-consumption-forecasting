# %%
import pandas as pd
from datetime import datetime as dt

# %%
df = pd.read_csv('CC_LCL-FullData.csv')

# %%
len(df)
# Out:
# 167932474

# %%
df.isnull().sum()
# Out:
# LCLid                      0
# stdorToU                   0
# DateTime                   0
# KWH/hh (per half hour)     0
# dtype: int64

# %%
df.drop('stdorToU',axis=1,inplace=True)

# %%
df.head(15)
# Out:
#         LCLid                     DateTime KWH/hh (per half hour)
# 0   MAC000002  2012-10-12 00:30:00.0000000                      0
# 1   MAC000002  2012-10-12 01:00:00.0000000                      0
# 2   MAC000002  2012-10-12 01:30:00.0000000                      0
# 3   MAC000002  2012-10-12 02:00:00.0000000                      0
# 4   MAC000002  2012-10-12 02:30:00.0000000                      0
# 5   MAC000002  2012-10-12 03:00:00.0000000                      0
# 6   MAC000002  2012-10-12 03:30:00.0000000                      0
# 7   MAC000002  2012-10-12 04:00:00.0000000                      0
# 8   MAC000002  2012-10-12 04:30:00.0000000                      0
# 9   MAC000002  2012-10-12 05:00:00.0000000                      0
# 10  MAC000002  2012-10-12 05:30:00.0000000                      0
# 11  MAC000002  2012-10-12 06:00:00.0000000                      0
# 12  MAC000002  2012-10-12 06:30:00.0000000                      0
# 13  MAC000002  2012-10-12 07:00:00.0000000                      0
# 14  MAC000002  2012-10-12 07:30:00.0000000                      0

# %%
df.duplicated(subset=['DateTime', 'LCLid']).sum()
# Out:
# 115453

# %%
df[df.duplicated(subset=['DateTime', 'LCLid'])].head()
# Out:
#           LCLid                     DateTime KWH/hh (per half hour)
# 383   MAC000002  2012-10-20 00:00:00.0000000                    0.2
# 1823  MAC000002  2012-11-20 00:00:00.0000000                  0.258
# 3312  MAC000002  2012-12-21 00:00:00.0000000                  0.238
# 4801  MAC000002  2013-01-21 00:00:00.0000000                   0.21
# 6290  MAC000002  2013-02-21 00:00:00.0000000                  0.216

# %%
df.drop_duplicates(subset=['DateTime', 'LCLid'], inplace=True)

# %%
df.duplicated(subset=['DateTime', 'LCLid']).sum()
# Out:
# 0

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
# Create 'Day' column with just the date part of 'DateTime'
df['Day'] = df['DateTime'].dt.normalize()
# Drop the 'DateTime' column
df.drop('DateTime', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167817021 entries, 0 to 167932473
# Data columns (total 3 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   LCLid                    object
#  1   KWH/hh (per half hour)   object
#  2   Day                      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 5.0+ GB

# %%
df.head()
# Out:
#        LCLid KWH/hh (per half hour)         Day
# 0  MAC000002                      0  2012-10-12
# 1  MAC000002                      0  2012-10-12
# 2  MAC000002                      0  2012-10-12
# 3  MAC000002                      0  2012-10-12
# 4  MAC000002                      0  2012-10-12

# %%
df[df['Day'] == '2011-11-28']
# Out:
#                LCLid KWH/hh (per half hour)         Day
# 4354870    MAC000145                  0.162  2011-11-28
# 4354871    MAC000145                  0.106  2011-11-28
# 4354872    MAC000145                  0.154  2011-11-28
# 4354873    MAC000145                  0.152  2011-11-28
# 4354874    MAC000145                  0.107  2011-11-28
# ...              ...                     ...        ...
# 135403405  MAC000198                  0.193  2011-11-28
# 135403406  MAC000198                  0.142  2011-11-28
# 135403407  MAC000198                  0.212  2011-11-28
# 135403408  MAC000198                  0.327  2011-11-28
# 135403409  MAC000198                  0.154  2011-11-28
#
# [2319 rows x 3 columns]

# %%
# Convert 'Null' strings to actual NaN values
df['KWH/hh (per half hour) '] = pd.to_numeric(df['KWH/hh (per half hour) '], errors='coerce')

# %%
# Now interpolate the missing values using linear interpolation
df['KWH/hh (per half hour) '] = df['KWH/hh (per half hour) '].interpolate(method='linear')

# %%
df['KWH/hh (per half hour) '].isnull().sum()
# Out:
# 0

# %%
df.LCLid.unique()
# Out:
# array(['MAC000002', 'MAC000003', 'MAC000004', ..., 'MAC005557',
#        'MAC005564', 'MAC005565'], dtype=object)

# %% [markdown]
# **House Count**
# > In the dataset we see that the number of households for which energy data was collected across different days are different. This is probably due to the gradually increasing adoption of smart meters in London.  This could lead to false interpretation that the energy for a particular day might be high when it could be that the data was only collected for more number of houses.

# %%
grouped_df = df.groupby(['Day', 'LCLid'])['KWH/hh (per half hour) '].sum().reset_index()

# %%
len(grouped_df)
# Out:
# 3510433

# %%
grouped_df.head()
# Out:
#          Day      LCLid  KWH/hh (per half hour)
# 0 2011-11-23  MAC000145                    8.952
# 1 2011-11-23  MAC000146                    5.619
# 2 2011-11-23  MAC000147                    3.036
# 3 2011-11-23  MAC000148                    1.283
# 4 2011-11-23  MAC000149                    2.287

# %%
grouped_df.rename(columns={'KWH/hh (per half hour) ': 'Total_Daily_Consumption'}, inplace=True)

# %%
housecount = grouped_df.groupby('Day')[['LCLid']].nunique()

# %%
housecount.plot(figsize=(25,5))
# Out:
# <Axes: xlabel='Day'>

# %%
# Group 'grouped_df' by 'Day' and sum the 'Total_Daily_Consumption'
grouped_df = grouped_df.groupby('Day')['Total_Daily_Consumption'].sum().reset_index()
# Merge the summed 'grouped_df' with 'housecount' on 'Day'
final_df = grouped_df.merge(housecount, on='Day')
# Reset the index of 'final_df'
final_df = final_df.reset_index(drop=True)

# %%
final_df.head()
# Out:
#          Day  Total_Daily_Consumption  LCLid
# 0 2011-11-23                90.385000     13
# 1 2011-11-24               213.412000     25
# 2 2011-11-25               303.993000     32
# 3 2011-11-26               420.976000     41
# 4 2011-11-27               444.883001     41

# %%
len(final_df)
# Out:
# 829

# %%
final_df.to_hdf('cleaned_energy_data.h5', key='df', mode='w')

# %% [markdown]
# ### Merging with other factors: weather, holiday

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import date as dt
loaded_df = pd.read_hdf('cleaned_energy_data.h5', key='df')

# %%
loaded_df['avg_energy'] =  loaded_df['Total_Daily_Consumption']/loaded_df['LCLid']
print("Starting Point of Data at Day Level",min(loaded_df.Day))
print("Ending Point of Data at Day Level",max(loaded_df.Day))
# Out:
# Starting Point of Data at Day Level 2011-11-23 00:00:00
# Ending Point of Data at Day Level 2014-02-28 00:00:00

# %% [markdown]
# > # Weather Data

# %%
weather = pd.read_csv('weather_daily_darksky.csv')
weather.head(4)
# Out:
#    temperatureMax   temperatureMaxTime  windBearing               icon  \
# 0           11.96  2011-11-11 23:00:00          123                fog
# 1            8.59  2011-12-11 14:00:00          198  partly-cloudy-day
# 2           10.33  2011-12-27 02:00:00          225  partly-cloudy-day
# 3            8.07  2011-12-02 23:00:00          232               wind
#
#    dewPoint   temperatureMinTime  cloudCover  windSpeed  pressure  \
# 0      9.40  2011-11-11 07:00:00        0.79       3.88   1016.08
# 1      4.49  2011-12-11 01:00:00        0.56       3.94   1007.71
# 2      5.47  2011-12-27 23:00:00        0.85       3.54   1032.76
# 3      3.69  2011-12-02 07:00:00        0.32       3.00   1012.12
#
#   apparentTemperatureMinTime  ...  temperatureHigh          sunriseTime  \
# 0        2011-11-11 07:00:00  ...            10.87  2011-11-11 07:12:14
# 1        2011-12-11 02:00:00  ...             8.59  2011-12-11 07:57:02
# 2        2011-12-27 22:00:00  ...            10.33  2011-12-27 08:07:06
# 3        2011-12-02 07:00:00  ...             7.36  2011-12-02 07:46:09
#
#    temperatureHighTime          uvIndexTime  \
# 0  2011-11-11 19:00:00  2011-11-11 11:00:00
# 1  2011-12-11 14:00:00  2011-12-11 12:00:00
# 2  2011-12-27 14:00:00  2011-12-27 00:00:00
# 3  2011-12-02 12:00:00  2011-12-02 10:00:00
#
#                                              summary   temperatureLowTime  \
# 0                             Foggy until afternoon.  2011-11-11 19:00:00
# 1                  Partly cloudy throughout the day.  2011-12-12 07:00:00
# 2                  Mostly cloudy throughout the day.  2011-12-27 23:00:00
# 3  Partly cloudy throughout the day and breezy ov...  2011-12-02 19:00:00
#
#    apparentTemperatureMin  apparentTemperatureMaxTime  \
# 0                    6.48         2011-11-11 23:00:00
# 1                    0.11         2011-12-11 20:00:00
# 2                    5.59         2011-12-27 02:00:00
# 3                    0.46         2011-12-02 12:00:00
#
#   apparentTemperatureLowTime moonPhase
# 0        2011-11-11 19:00:00      0.52
# 1        2011-12-12 08:00:00      0.53
# 2        2011-12-28 00:00:00      0.10
# 3        2011-12-02 19:00:00      0.25
#
# [4 rows x 32 columns]

# %%
weather.time.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 882 entries, 0 to 881
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 882 non-null    object
# dtypes: object(1)
# memory usage: 7.0+ KB

# %%
weather['Day'] = pd.to_datetime(weather['time'])
weather.drop('time',inplace=True,axis=1)
weather['Day'] = weather['Day'].dt.normalize()

# %%
# selecting numeric variables
weather = weather[['temperatureMax', 'windBearing', 'dewPoint', 'cloudCover', 'windSpeed',
       'pressure', 'apparentTemperatureHigh', 'visibility', 'humidity',
       'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex',
       'temperatureLow', 'temperatureMin', 'temperatureHigh',
       'apparentTemperatureMin', 'moonPhase','Day']]
weather = weather.dropna()

# %%
energy_weather=loaded_df.merge(weather,on='Day')
energy_weather.head(2)
# Out:
#          Day  Total_Daily_Consumption  LCLid  avg_energy  temperatureMax  \
# 0 2011-11-23                   90.385     13    6.952692           10.36
# 1 2011-11-24                  213.412     25    8.536480           12.93
#
#    windBearing  dewPoint  cloudCover  windSpeed  pressure  ...  visibility  \
# 0          229      6.29        0.36       2.04   1027.12  ...        8.06
# 1          204      8.56        0.41       4.04   1027.22  ...       10.64
#
#    humidity  apparentTemperatureLow  apparentTemperatureMax  uvIndex  \
# 0      0.93                    6.56                   10.36      1.0
# 1      0.89                    7.30                   12.93      1.0
#
#    temperatureLow  temperatureMin  temperatureHigh  apparentTemperatureMin  \
# 0            8.24            3.81            10.36                    2.18
# 1            9.71            8.56            12.93                    7.01
#
#    moonPhase
# 0       0.94
# 1       0.97
#
# [2 rows x 21 columns]

# %% [markdown]
# > # Holiday

# %%
holiday = pd.read_csv('uk_bank_holidays.csv')
holiday['Bank holidays'] = pd.to_datetime(holiday['Bank holidays']).dt.normalize()
holiday.head(4)
# Out:
#   Bank holidays                                          Type
# 0    2012-12-26                                    Boxing Day
# 1    2012-12-25                                 Christmas Day
# 2    2012-08-27                           Summer bank holiday
# 3    2012-05-06  Queen?s Diamond Jubilee (extra bank holiday)

# %%
holiday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Bank holidays  25 non-null     datetime64[ns]
#  1   Type           25 non-null     object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 532.0+ bytes

# %%
Final_DF = energy_weather.merge(holiday, left_on = 'Day',right_on = 'Bank holidays',how = 'left')

# %%
Final_DF['holiday_ind'] = np.where(Final_DF['Bank holidays'].isna(),0,1)

# %%
Final_DF[Final_DF['holiday_ind']==1]
# Out:
#            Day  Total_Daily_Consumption  LCLid  avg_energy  temperatureMax  \
# 70  2012-02-01              8150.828998    590   13.814964            3.36
# 136 2012-04-06             14166.792006   1342   10.556477           10.48
# 166 2012-05-06             25069.815997   2358   10.631813           14.48
# 195 2012-06-04             33059.635000   3741    8.837112           15.00
# 226 2012-07-05             35166.288998   4348    8.087923           18.70
# 279 2012-08-27             39589.041998   4761    8.315279           22.50
# 287 2012-09-04             39716.142000   4763    8.338472           19.97
# 398 2012-12-25             68988.858001   5515   12.509312            9.14
# 399 2012-12-26             64350.884999   5513   11.672571           10.18
# 405 2013-01-01             65269.368001   5513   11.839174            7.49
# 408 2013-01-04             62942.145998   5514   11.414970           10.79
# 492 2013-03-29             66136.130006   5407   12.231576            5.31
# 552 2013-05-27             45846.575997   5358    8.556658           12.13
# 561 2013-06-05             42889.653000   5353    8.012265           20.88
# 643 2013-08-26             42010.849999   5250    8.002067           22.78
# 763 2013-12-25             64006.147991   5103   12.542847            7.19
# 764 2013-12-26             59479.846003   5103   11.655859            7.64
#
#      windBearing  dewPoint  cloudCover  windSpeed  pressure  ...  \
# 70            53     -4.69        0.36       5.45   1032.32  ...
# 136            2      4.36        0.72       2.09   1012.32  ...
# 166          160      6.55        0.52       2.54   1014.29  ...
# 195          160      8.14        0.51       3.42   1014.65  ...
# 226          193     13.22        0.39       2.46   1007.45  ...
# 279          224     13.49        0.39       4.17   1012.79  ...
# 287            5      7.83        0.27       3.26   1026.74  ...
# 398          225      6.27        0.56       4.39    995.66  ...
# 399          230      5.73        0.39       5.05   1004.15  ...
# 405          257      2.40        0.43       4.00   1016.89  ...
# 408          266      7.31        0.83       4.28   1037.15  ...
# 492           55     -4.23        0.59       3.52   1010.88  ...
# 552          130      8.67        0.67       1.48   1000.65  ...
# 561           58      8.33        0.23       4.28   1021.53  ...
# 643            3     10.67        0.23       1.89   1018.60  ...
# 763          194      2.57        0.03       2.47    984.66  ...
# 764          219      2.86        0.49       2.27    995.06  ...
#
#      apparentTemperatureMax  uvIndex  temperatureLow  temperatureMin  \
# 70                    -1.86      1.0           -1.66           -0.92
# 136                   10.48      3.0            6.52            6.86
# 166                   14.48      4.0           10.43            5.20
# 195                   15.00      6.0           11.54            7.54
# 226                   18.70      5.0           13.42           14.78
# 279                   22.50      4.0           14.74           14.97
# 287                   19.97      3.0            8.67           12.07
# 398                    6.49      1.0            4.83            6.46
# 399                   10.18      1.0            6.42            4.83
# 405                    4.38      1.0            4.42            3.31
# 408                   10.79      1.0            8.07            8.17
# 492                    1.71      3.0            0.94           -0.52
# 552                   12.13      4.0            8.38            9.78
# 561                   20.88      3.0           10.02            8.73
# 643                   22.78      4.0           12.45           12.82
# 763                    4.98      1.0            2.87            3.74
# 764                    4.53      0.0            4.29            2.87
#
#      temperatureHigh  apparentTemperatureMin  moonPhase  Bank holidays  \
# 70              3.36                   -5.98       0.29     2012-02-01
# 136            10.48                    6.42       0.53     2012-04-06
# 166            14.48                    4.48       0.55     2012-05-06
# 195            15.00                    7.54       0.54     2012-06-04
# 226            18.70                   14.78       0.60     2012-07-05
# 279            22.50                   14.97       0.39     2012-08-27
# 287            19.97                   12.07       0.66     2012-09-04
# 398             9.14                    3.86       0.41     2012-12-25
# 399            10.18                    1.34       0.44     2012-12-26
# 405             5.76                    0.23       0.63     2013-01-01
# 408            10.17                    5.70       0.73     2013-01-04
# 492             5.31                   -2.99       0.57     2013-03-29
# 552            11.88                    9.12       0.62     2013-05-27
# 561            20.88                    6.66       0.93     2013-06-05
# 643            22.78                   12.82       0.72     2013-08-26
# 763             7.19                    0.23       0.75     2013-12-25
# 764             4.29                   -0.06       0.78     2013-12-26
#
#                                              Type  holiday_ind
# 70                New Year?s Day (substitute day)            1
# 136          Spring bank holiday (substitute day)            1
# 166  Queen?s Diamond Jubilee (extra bank holiday)            1
# 195                                   Good Friday            1
# 226                        Early May bank holiday            1
# 279                           Summer bank holiday            1
# 287                                 Easter Monday            1
# 398                                 Christmas Day            1
# 399                                    Boxing Day            1
# 405                                New Year?s Day            1
# 408                                 Easter Monday            1
# 492                                   Good Friday            1
# 552                           Spring bank holiday            1
# 561                        Early May bank holiday            1
# 643                           Summer bank holiday            1
# 763                                 Christmas Day            1
# 764                                    Boxing Day            1
#
# [17 rows x 24 columns]

# %%
Final_DF.to_hdf('data.h5',mode = 'w', key = 'df')
# Out:
# C:\Users\souts\AppData\Local\Temp\ipykernel_20760\1085979173.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block4_values] [items->Index(['Type'], dtype='object')]
#
#   Final_DF.to_hdf('data.h5',mode = 'w', key = 'df')

# %%
Final_DF.to_csv('data.csv',mode='w')
